# %% [markdown]
# <a href="https://colab.research.google.com/github/mbroda2000/Python_and_ML_Repository/blob/while_variant/zad5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
data = pd.read_csv('drive/MyDrive/exercise_dataset.csv')

# %%
import seaborn as sns
import matplotlib.pyplot as plt




sns.boxplot(x='Gender', y='Calories Burn', data=data)
plt.title('Calories Burn by Gender')
plt.xlabel('Gender')
plt.ylabel('Calories Burn')
plt.show()
plt.savefig('calories_burn_by_gender.png', dpi=600)

# %%
import matplotlib.pyplot as plt


plt.figure(figsize=(8, 6))
plt.hist(data['Age'], bins=20, edgecolor='k', color='skyblue', alpha=0.7)
plt.title('Age Distribution', fontsize=16)
plt.xlabel('Age', fontsize=14)
plt.ylabel('Number of People', fontsize=14)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
import matplotlib.pyplot as plt


plt.figure(figsize=(8, 6))
exercise_intensity_counts = data['Exercise Intensity'].value_counts().sort_index()
plt.bar(exercise_intensity_counts.index, exercise_intensity_counts.values, color='green', alpha=0.7)
plt.title('Exercise Intensity Distribution', fontsize=16)
plt.xlabel('Exercise Intensity', fontsize=14)
plt.ylabel('Count', fontsize=14)
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 6))
plt.scatter(data['Dream Weight'], data['Actual Weight'], alpha=0.5, color='cyan')
plt.title('Dream Weight vs Actual Weight', fontsize=16)
plt.xlabel('Dream Weight', fontsize=14)
plt.ylabel('Actual Weight', fontsize=14)
plt.grid(linestyle='--', alpha=0.7)
plt.show()

# %%
# Import seaborn
import seaborn as sns
# Apply the default theme
sns.set_theme()

sns.scatterplot(x=data['Age'], y=data['BMI'])
sns.scatterplot(data = data, x='Age', y='BMI')


plt.figure(figsize=(10, 5))

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set_theme()


sns.scatterplot(data=data, x='Age', y='BMI', hue='Gender')
plt.title('Age and BMI regarding gender')
plt.xlabel('Age')
plt.ylabel('BMI')
plt.legend(title='Gender')
plt.figure(figsize=(10, 5))
plt.show()
